# %% [markdown]
# ### 2023 Data

# %%
import pandas as pd
import numpy as np

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2023" # fetching all the 2023 movies from wikipedia
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = pd.concat([df1,df2,df3,df4],ignore_index=True) #concat all the dataframes in a single for preprocessing
df
# Out:
#              Opening  Opening.1                 Title  \
# 0      J A N U A R Y          6                 M3GAN
# 1      J A N U A R Y          6           The Old Way
# 2      J A N U A R Y         11  The Devil Conspiracy
# 3      J A N U A R Y         13                 Plane
# 4      J A N U A R Y         13           House Party
# ..               ...        ...                   ...
# 338  D E C E M B E R         22                Memory
# 339  D E C E M B E R         25      The Color Purple
# 340  D E C E M B E R         25  The Boys in the Boat
# 341  D E C E M B E R         25               Ferrari
# 342  D E C E M B E R         29            Good Grief
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / A...
# 1                           Saban Films / Saturn Films
# 2                                 Samuel Goldwyn Films
# 3    Lionsgate / MadRiver Pictures / Di Bonaventura...
# 4              Warner Bros. Pictures / New Line Cinema
# ..                                                 ...
# 338                       Ketchup Entertainment / Mubi
# 339  Warner Bros. Pictures / Amblin Entertainment /...
# 340          Metro-Goldwyn-Mayer / Smokehouse Pictures
# 341            Neon / STXfilms / Ketchup Entertainment
# 342                                            Netflix
#
#                                          Cast and crew   Ref.
# 0    Gerard Johnstone (director); Akela Cooper (scr...    [3]
# 1    Brett Donowho (director); Carl W. Lucas (scree...    [4]
# 2    Nathan Frankowski (director); Ed Alan (screenp...    [5]
# 3    Jean-François Richet (director); Charles Cummi...    [6]
# 4    Calmatic (director); Jamal Olori, Stephen Glov...    [7]
# ..                                                 ...    ...
# 338  Michel Franco (director/screenplay); Jessica C...  [325]
# 339  Blitz Bazawule (director), Marcus Gardley (scr...  [326]
# 340  George Clooney (director), Mark L. Smith (scre...  [327]
# 341  Michael Mann (director), Troy Kennedy Martin (...  [328]
# 342  Dan Levy (director/screenplay); Dan Levy, Ruth...  [329]
#
# [343 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['Opening', 'Opening.1', 'Title', 'Production company', 'Cast and crew',
#        'Ref.'],
#       dtype='object')

# %% [markdown]
# #### As it is observed in the above table, we do not have the genre column so we will get the genre data from IMDb. You will need to create an API key in order to access the API key.
#
# ### pip install tmdbv3api

# %%
#get your API Key here: https://www.themoviedb.org/settings/api
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()

api = 'cf1e5b9d8cf31e19913dd6bc256abb2a'
tmdb.api_key=api # insert your api key here

# %%
import requests

from tmdbv3api import Movie

tmdb_movie = Movie()

def get_genre(x):
    genres = []
    
    try:
        # Search for the movie title
        result = tmdb_movie.search(x)
        
        # Check if any results were found
        if not result:
            return 'No results found'

        # Get the movie ID from the first result
        movie_id = result[0].id
        
        # Fetch movie details using the movie ID
        response = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb.api_key}')
        data_json = response.json()
        
        # Check if the movie has genres
        if 'genres' in data_json and data_json['genres']:
            for genre in data_json['genres']:
                genres.append(genre['name'])
            return ' '.join(genres)  # Return genres as a space-separated string
        else:
            return np.nan
    
    except Exception as e:
        # Handle any exceptions (e.g., connection issues, API errors)
        return f'Error: {str(e)}'

# Example usage to map genres to the DataFrame
df['genres'] = df['Title'].map(lambda x: get_genre(x))

# %%
# df['genres']= df['Title'].map(lambda x : get_genre(x))

df.head()
# Out:
#          Opening  Opening.1                 Title  \
# 0  J A N U A R Y          6                 M3GAN
# 1  J A N U A R Y          6           The Old Way
# 2  J A N U A R Y         11  The Devil Conspiracy
# 3  J A N U A R Y         13                 Plane
# 4  J A N U A R Y         13           House Party
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / A...
# 1                         Saban Films / Saturn Films
# 2                               Samuel Goldwyn Films
# 3  Lionsgate / MadRiver Pictures / Di Bonaventura...
# 4            Warner Bros. Pictures / New Line Cinema
#
#                                        Cast and crew Ref.  \
# 0  Gerard Johnstone (director); Akela Cooper (scr...  [3]
# 1  Brett Donowho (director); Carl W. Lucas (scree...  [4]
# 2  Nathan Frankowski (director); Ed Alan (screenp...  [5]
# 3  Jean-François Richet (director); Charles Cummi...  [6]
# 4  Calmatic (director); Jamal Olori, Stephen Glov...  [7]
#
#                                     genres
# 0                   Science Fiction Horror
# 1                            Western Drama
# 2  Horror Fantasy Science Fiction Thriller
# 3                Action Adventure Thriller
# 4                                   Comedy

# %%
import re
import pandas as pd

def extract_info2(text):
    # Check if the text is None or not a string
    if not isinstance(text, str):
        return pd.Series([None, None, None, None])
    
    # Initialize the director to None
    director_name = None
    # Initialize the actors to None
    actor_1, actor_2, actor_3 = None, None, None
    
    # Check if the text contains a director's name and role(s)
    director_match = re.search(r'([a-zA-Z\s]+) \(([^)]+)\)', text)  # Extract name and roles inside parentheses
    if director_match:
        name = director_match.group(1).strip()  # Extract the name (e.g., Michael Moore)
        roles = director_match.group(2).strip()  # Extract the roles (e.g., director/screenplay/narrator)
        
        # If 'director' is in the roles, assign only the name to the director column
        if 'director' in roles:
            director_name = name  # Only assign the name to the director column if 'director' is present in the roles
            
            # Remove the director's name from the actors list to avoid duplication
            text = text.replace(name + " (" + roles + ")", "")  # Remove the entire director's entry

    # Extract actors from the cast and crew field (after the last semicolon)
    actors = re.split(r';', text)[-1].strip().split(', ')  # Split by semicolon and take actors from the last part
    
    # Remove the director from the actors list (if it was listed there)
    actors = [actor for actor in actors if actor != director_name]
    
    # Assign actors if they exist
    actor_1 = actors[0] if len(actors) > 0 else None
    actor_2 = actors[1] if len(actors) > 1 else None
    actor_3 = actors[2] if len(actors) > 2 else None

    # Return the extracted information in a pandas Series
    return pd.Series([director_name, actor_1, actor_2, actor_3])

# %%
df[['director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name']] = df['Cast and crew'].apply(extract_info2)

# %%
df=df.rename(columns={'Title':'movie_title'})
df.head(2)
# Out:
#          Opening  Opening.1  movie_title  \
# 0  J A N U A R Y          6        M3GAN
# 1  J A N U A R Y          6  The Old Way
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / A...
# 1                         Saban Films / Saturn Films
#
#                                        Cast and crew Ref.  \
# 0  Gerard Johnstone (director); Akela Cooper (scr...  [3]
# 1  Brett Donowho (director); Carl W. Lucas (scree...  [4]
#
#                    genres     director_name      actor_1_name  \
# 0  Science Fiction Horror  Gerard Johnstone  Allison Williams
# 1           Western Drama     Brett Donowho      Nicolas Cage
#
#            actor_2_name actor_3_name
# 0         Violet McGraw  Amie Donald
# 1  Ryan Kiera Armstrong         None

# %%
new_df23 = df[['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
new_df23
# Out:
#          director_name      actor_1_name          actor_2_name  \
# 0     Gerard Johnstone  Allison Williams         Violet McGraw
# 1        Brett Donowho      Nicolas Cage  Ryan Kiera Armstrong
# 2    Nathan Frankowski   Alice Orr-Ewing             Joe Doyle
# 3           ois Richet     Gerard Butler           Mike Colter
# 4             Calmatic        Tosin Cole        Jacob Latimore
# ..                 ...               ...                   ...
# 338      Michel Franco  Jessica Chastain       Peter Sarsgaard
# 339     Blitz Bazawule  Fantasia Barrino      Taraji P. Henson
# 340     George Clooney     Callum Turner         Joel Edgerton
# 341       Michael Mann       Adam Driver         Penelope Cruz
# 342           Dan Levy        Ruth Negga          Himesh Patel
#
#          actor_3_name                                   genres  \
# 0         Amie Donald                   Science Fiction Horror
# 1                None                            Western Drama
# 2        Eveline Hall  Horror Fantasy Science Fiction Thriller
# 3            Yoson An                Action Adventure Thriller
# 4        Karen Obilom                                   Comedy
# ..                ...                                      ...
# 338     Merritt Wever                    Action Thriller Crime
# 339   Danielle Brooks                                    Drama
# 340    Peter Guinness                            Drama History
# 341  Shailene Woodley                            History Drama
# 342       Celia Imrie                             Comedy Drama
#
#               movie_title
# 0                   M3GAN
# 1             The Old Way
# 2    The Devil Conspiracy
# 3                   Plane
# 4             House Party
# ..                    ...
# 338                Memory
# 339      The Color Purple
# 340  The Boys in the Boat
# 341               Ferrari
# 342            Good Grief
#
# [343 rows x 6 columns]

# %%
new_df23.shape
# Out:
# (343, 6)

# %%
new_df23.isna().sum()
# Out:
# director_name     3
# actor_1_name      0
# actor_2_name      4
# actor_3_name     20
# genres            0
# movie_title       0
# dtype: int64

# %%
new_df23.dropna(thresh=1,inplace=True)
# Out:
# C:\Users\ARMS\AppData\Local\Temp\ipykernel_7424\2306608193.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df23.dropna(thresh=1,inplace=True)

# %%
new_df23.isna().sum()
# Out:
# director_name     3
# actor_1_name      0
# actor_2_name      4
# actor_3_name     20
# genres            0
# movie_title       0
# dtype: int64

# %%
new_df23.fillna('unknown',inplace=True)
# Out:
# C:\Users\ARMS\AppData\Local\Temp\ipykernel_7424\2446183395.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df23.fillna('unknown',inplace=True)

# %%
new_df23.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# dtype: int64

# %%
new_df23['movie_title']= new_df23['movie_title'].str.lower()
# Out:
# C:\Users\ARMS\AppData\Local\Temp\ipykernel_7424\763944369.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df23['movie_title']= new_df23['movie_title'].str.lower()

# %%
new_df23.sample(2)
# Out:
#             director_name           actor_1_name    actor_2_name  \
# 260       Martin Scorsese      Leonardo DiCaprio  Robert De Niro
# 113  Kyle Patrick Alvarez  Isaiah Russell-Bailey   Mckenna Grace
#
#        actor_3_name                                   genres  \
# 260  Lily Gladstone                      Crime History Drama
# 113   Billy Barratt  Science Fiction Action Adventure Family
#
#                     movie_title
# 260  killers of the flower moon
# 113                      crater

# %%
new_df23['comb'] = new_df23['actor_1_name'] + ' ' + new_df23['actor_2_name'] + ' '+ new_df23['actor_3_name'] + ' '+ new_df23['director_name'] +' ' + new_df23['genres']
new_df23
# Out:
# C:\Users\ARMS\AppData\Local\Temp\ipykernel_7424\1789900429.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df23['comb'] = new_df23['actor_1_name'] + ' ' + new_df23['actor_2_name'] + ' '+ new_df23['actor_3_name'] + ' '+ new_df23['director_name'] +' ' + new_df23['genres']
#          director_name      actor_1_name          actor_2_name  \
# 0     Gerard Johnstone  Allison Williams         Violet McGraw
# 1        Brett Donowho      Nicolas Cage  Ryan Kiera Armstrong
# 2    Nathan Frankowski   Alice Orr-Ewing             Joe Doyle
# 3           ois Richet     Gerard Butler           Mike Colter
# 4             Calmatic        Tosin Cole        Jacob Latimore
# ..                 ...               ...                   ...
# 338      Michel Franco  Jessica Chastain       Peter Sarsgaard
# 339     Blitz Bazawule  Fantasia Barrino      Taraji P. Henson
# 340     George Clooney     Callum Turner         Joel Edgerton
# 341       Michael Mann       Adam Driver         Penelope Cruz
# 342           Dan Levy        Ruth Negga          Himesh Patel
#
#          actor_3_name                                   genres  \
# 0         Amie Donald                   Science Fiction Horror
# 1             unknown                            Western Drama
# 2        Eveline Hall  Horror Fantasy Science Fiction Thriller
# 3            Yoson An                Action Adventure Thriller
# 4        Karen Obilom                                   Comedy
# ..                ...                                      ...
# 338     Merritt Wever                    Action Thriller Crime
# 339   Danielle Brooks                                    Drama
# 340    Peter Guinness                            Drama History
# 341  Shailene Woodley                            History Drama
# 342       Celia Imrie                             Comedy Drama
#
#               movie_title                                               comb
# 0                   m3gan  Allison Williams Violet McGraw Amie Donald Ger...
# 1             the old way  Nicolas Cage Ryan Kiera Armstrong unknown Bret...
# 2    the devil conspiracy  Alice Orr-Ewing Joe Doyle Eveline Hall Nathan ...
# 3                   plane  Gerard Butler Mike Colter Yoson An ois Richet ...
# 4             house party  Tosin Cole Jacob Latimore Karen Obilom Calmati...
# ..                    ...                                                ...
# 338                memory  Jessica Chastain Peter Sarsgaard Merritt Wever...
# 339      the color purple  Fantasia Barrino Taraji P. Henson Danielle Bro...
# 340  the boys in the boat  Callum Turner Joel Edgerton Peter Guinness Geo...
# 341               ferrari  Adam Driver Penelope Cruz Shailene Woodley Mic...
# 342            good grief  Ruth Negga Himesh Patel Celia Imrie Dan Levy C...
#
# [343 rows x 7 columns]

# %%
old = pd.read_csv('last1_data.csv')

old.sample(2)
# Out:
#      director_name   actor_1_name   actor_2_name   actor_3_name  \
# 1807   Matt Reeves     Mike Vogel    Ben Feldman    Liza Lapira
# 6114  Taylor Swift  Jack Antonoff  Aaron Dessner  Justin Vernon
#
#                                   movie_title                          genres  \
# 1807                              cloverfield  Action Adventure Horror Sci-Fi
# 6114  folklore: the long pond studio sessions               Music Documentary
#
#                                                    comb
# 1807  Mike Vogel Ben Feldman Liza Lapira Matt Reeves...
# 6114  Jack Antonoff Aaron Dessner Justin Vernon Tayl...

# %%
final = pd.concat([old,new_df23],ignore_index=True)
final
# Out:
#           director_name      actor_1_name      actor_2_name  \
# 0         James Cameron       CCH Pounder  Joel David Moore
# 1        Gore Verbinski       Johnny Depp     Orlando Bloom
# 2            Sam Mendes   Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan         Tom Hardy    Christian Bale
# 4           Doug Walker       Doug Walker        Rob Walker
# ...                 ...               ...               ...
# 7197      Michel Franco  Jessica Chastain   Peter Sarsgaard
# 7198     Blitz Bazawule  Fantasia Barrino  Taraji P. Henson
# 7199     George Clooney     Callum Turner     Joel Edgerton
# 7200       Michael Mann       Adam Driver     Penelope Cruz
# 7201           Dan Levy        Ruth Negga      Himesh Patel
#
#               actor_3_name                                        movie_title  \
# 0                Wes Studi                                             avatar
# 1           Jack Davenport           pirates of the caribbean: at world's end
# 2         Stephanie Sigman                                            spectre
# 3     Joseph Gordon-Levitt                              the dark knight rises
# 4                  unknown  star wars: episode vii - the force awakens    ...
# ...                    ...                                                ...
# 7197         Merritt Wever                                             memory
# 7198       Danielle Brooks                                   the color purple
# 7199        Peter Guinness                               the boys in the boat
# 7200      Shailene Woodley                                            ferrari
# 7201           Celia Imrie                                         good grief
#
#                                genres  \
# 0     Action Adventure Fantasy Sci-Fi
# 1            Action Adventure Fantasy
# 2           Action Adventure Thriller
# 3                     Action Thriller
# 4                         Documentary
# ...                               ...
# 7197            Action Thriller Crime
# 7198                            Drama
# 7199                    Drama History
# 7200                    History Drama
# 7201                     Comedy Drama
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 7197  Jessica Chastain Peter Sarsgaard Merritt Wever...
# 7198  Fantasia Barrino Taraji P. Henson Danielle Bro...
# 7199  Callum Turner Joel Edgerton Peter Guinness Geo...
# 7200  Adam Driver Penelope Cruz Shailene Woodley Mic...
# 7201  Ruth Negga Himesh Patel Celia Imrie Dan Levy C...
#
# [7202 rows x 7 columns]

# %%
final.isna().sum()
# Out:
# director_name    2
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# movie_title      0
# genres           0
# comb             0
# dtype: int64

# %%
final.dropna(inplace=True)

# %%
final.drop_duplicates(keep='last',inplace=True)

final
# Out:
#           director_name      actor_1_name      actor_2_name  \
# 0         James Cameron       CCH Pounder  Joel David Moore
# 1        Gore Verbinski       Johnny Depp     Orlando Bloom
# 2            Sam Mendes   Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan         Tom Hardy    Christian Bale
# 4           Doug Walker       Doug Walker        Rob Walker
# ...                 ...               ...               ...
# 7197      Michel Franco  Jessica Chastain   Peter Sarsgaard
# 7198     Blitz Bazawule  Fantasia Barrino  Taraji P. Henson
# 7199     George Clooney     Callum Turner     Joel Edgerton
# 7200       Michael Mann       Adam Driver     Penelope Cruz
# 7201           Dan Levy        Ruth Negga      Himesh Patel
#
#               actor_3_name                                        movie_title  \
# 0                Wes Studi                                             avatar
# 1           Jack Davenport           pirates of the caribbean: at world's end
# 2         Stephanie Sigman                                            spectre
# 3     Joseph Gordon-Levitt                              the dark knight rises
# 4                  unknown  star wars: episode vii - the force awakens    ...
# ...                    ...                                                ...
# 7197         Merritt Wever                                             memory
# 7198       Danielle Brooks                                   the color purple
# 7199        Peter Guinness                               the boys in the boat
# 7200      Shailene Woodley                                            ferrari
# 7201           Celia Imrie                                         good grief
#
#                                genres  \
# 0     Action Adventure Fantasy Sci-Fi
# 1            Action Adventure Fantasy
# 2           Action Adventure Thriller
# 3                     Action Thriller
# 4                         Documentary
# ...                               ...
# 7197            Action Thriller Crime
# 7198                            Drama
# 7199                    Drama History
# 7200                    History Drama
# 7201                     Comedy Drama
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 7197  Jessica Chastain Peter Sarsgaard Merritt Wever...
# 7198  Fantasia Barrino Taraji P. Henson Danielle Bro...
# 7199  Callum Turner Joel Edgerton Peter Guinness Geo...
# 7200  Adam Driver Penelope Cruz Shailene Woodley Mic...
# 7201  Ruth Negga Himesh Patel Celia Imrie Dan Levy C...
#
# [7200 rows x 7 columns]

# %%
final.to_csv('last2_data.csv',index=False)
